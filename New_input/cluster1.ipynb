# %% [markdown]
# # Permodelan Cluster 1

# %% [markdown]
# Import segala pustaka (library) yang digunakan

# %%
import tensorflow as tf #untuk mempermudah pembuatan deep learning
import pandas as pd #mempermudah pembacaan data dengan ukuran besar (big data) dari data penjualan
import numpy as np #mempermudah pengolahan data dari library sebelumnya
import matplotlib.pyplot as plt #untuk mempermudah visualisasi
from sklearn.preprocessing import MinMaxScaler #untuk menskala data sehingga mudah dibaca dan diproses deep learning
# Out:
# c:\Users\Alvin Buana\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ## Pembacaan Data

# %% [markdown]
# Baca dataset train

# %%
data=pd.read_excel('ANTIBIOTIC ANTIFUNGAL ANTIVIRAL.xlsx',sheet_name='train',header=[0])
data
# Out:
#    KODE PRODUK  BULAN  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0          NaN      1           2           3           4           5
# 1        04073     37          49          25           8         103
# 2        18051     63          40           6          26          23
# 3        04176     29          21          19          14          40
# 4        18085    112         141          35          39         145
# 5        04177     76          44          66          56          91
# 6        04125     76          50          45          19          69
# 7        04132      5          42          27          16          25
# 8        04167     29          14          46          20          10
# 9        04148     20           8          14           2          15
# 10       04043      6           6          34           0           3
# 11       04149    558         467         841         495         495
# 12       04040     26          32           9          19          20
# 13       18071     28          62          20          15          14
# 14       04050     32          42          45          31          72
# 15       18074    132         138         128          98         139
# 16       18054     32           0          50          30          73
# 17       E1054      0           0           0          10          15
#
#     Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 46  \
# 0            6           7           8           9  ...           46
# 1           60          89          23          44  ...           13
# 2            9          -1          51          18  ...            0
# 3            6          14           2          14  ...          -17
# 4           15          57          63          45  ...         1294
# 5           35          65          47          32  ...           26
# 6           41          64          75          76  ...           48
# 7           20          28          11          38  ...            0
# 8           15          27          20          49  ...           10
# 9            5          19           9          26  ...            4
# 10           0           2           0          36  ...            9
# 11         393         339         309         596  ...           72
# 12           6          26          15          35  ...            9
# 13          10          60          40          31  ...            1
# 14          42          65          34          52  ...            6
# 15         109          28          47          92  ...           12
# 16          13          83          64          80  ...          143
# 17          63         228         223         177  ...            0
#
#     Unnamed: 47  Unnamed: 48  Unnamed: 49  Unnamed: 50  Unnamed: 51  \
# 0            47           48           49           50           51
# 1            54           39           10           34           30
# 2             5            3            2           -2            4
# 3             0           19           10            0            0
# 4            30          966          384         1017         1270
# 5            47           17           32           31           53
# 6            50           43           57           63           51
# 7             0            0            0            0            4
# 8            10           17           22           16           47
# 9             1            2            3            0            1
# 10           -8            5            0            0           20
# 11           65           65          110           41           26
# 12            4           19            3           14           10
# 13            0            0            0            0           13
# 14           38           24           29           22           36
# 15           36           47           25           13            8
# 16          130          103           93          110          287
# 17            0            5           -5           15            0
#
#     Unnamed: 52  Unnamed: 53  Unnamed: 54  Cluster
# 0            52           53           54      NaN
# 1            36           26           29      2.0
# 2             7           17            0      1.0
# 3            11            5            1      2.0
# 4           623          511           47      2.0
# 5            56           35           52      2.0
# 6            50           40           64      2.0
# 7            19            3            9      2.0
# 8            45           30            7      2.0
# 9             2            1            5      2.0
# 10            0            0            0      2.0
# 11           90           61           57      1.0
# 12           14            9           10      1.0
# 13            9           15           12      1.0
# 14            1           21            3      2.0
# 15            2            0           15      1.0
# 16           57           12           20      2.0
# 17            0            0            0      2.0
#
# [18 rows x 56 columns]

# %%
data_test=pd.read_excel('ANTIBIOTIC ANTIFUNGAL ANTIVIRAL.xlsx',sheet_name='test',header=[0])
data_test
# Out:
#    KODE PRODUK  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0          NaN          53          54          55          56          57
# 1        04073          26          29           8          19          57
# 2        18051          17           0           0           4          16
# 3        04176           5           1           3          13          12
# 4        18085         511          47        1079         302        1596
# 5        04177          35          52          45          87          16
# 6        04125          40          64          62         112          48
# 7        04132           3           9           3          10          22
# 8        04167          30           7          26          50          40
# 9        04148           1           5           1           4           0
# 10       04043           0           0           0           0           0
# 11       04149          61          57          48          76          82
# 12       04040           9          10           8           9           6
# 13       18071          15          12           0          18          29
# 14       04050          21           3          27           1          20
# 15       18074           0          15          38          35          10
# 16       18054          12          20          39          79          91
# 17       E1054           0           0           0           0           0
#
#     Unnamed: 6  Unnamed: 7  Unnamed: 8  Cluster
# 0           58          59          60      NaN
# 1           10           2          20      2.0
# 2            9           8           4      1.0
# 3            1           4           0      2.0
# 4            9         114          28      2.0
# 5           28          22          15      2.0
# 6           41          34          54      2.0
# 7            5           0           0      2.0
# 8           43          40          46      2.0
# 9            0          11         -11      2.0
# 10           0           0           0      2.0
# 11          24          30          -1      1.0
# 12           8           7           4      1.0
# 13           6          18          10      1.0
# 14          42           6          40      2.0
# 15          28          25          49      1.0
# 16         119         112          25      2.0
# 17           0           0           0      2.0

# %%
data.rename(data.iloc[0,1:-1],axis=1,inplace=True)
data = data.loc[1:,:]
data_test.rename(data_test.iloc[0,1:-1],axis=1,inplace=True)
data_test = data_test.loc[1:,:]

# %%
data
# Out:
#    KODE PRODUK    1    2    3    4    5    6    7    8    9  ...    46   47  \
# 1        04073   37   49   25    8  103   60   89   23   44  ...    13   54
# 2        18051   63   40    6   26   23    9   -1   51   18  ...     0    5
# 3        04176   29   21   19   14   40    6   14    2   14  ...   -17    0
# 4        18085  112  141   35   39  145   15   57   63   45  ...  1294   30
# 5        04177   76   44   66   56   91   35   65   47   32  ...    26   47
# 6        04125   76   50   45   19   69   41   64   75   76  ...    48   50
# 7        04132    5   42   27   16   25   20   28   11   38  ...     0    0
# 8        04167   29   14   46   20   10   15   27   20   49  ...    10   10
# 9        04148   20    8   14    2   15    5   19    9   26  ...     4    1
# 10       04043    6    6   34    0    3    0    2    0   36  ...     9   -8
# 11       04149  558  467  841  495  495  393  339  309  596  ...    72   65
# 12       04040   26   32    9   19   20    6   26   15   35  ...     9    4
# 13       18071   28   62   20   15   14   10   60   40   31  ...     1    0
# 14       04050   32   42   45   31   72   42   65   34   52  ...     6   38
# 15       18074  132  138  128   98  139  109   28   47   92  ...    12   36
# 16       18054   32    0   50   30   73   13   83   64   80  ...   143  130
# 17       E1054    0    0    0   10   15   63  228  223  177  ...     0    0
#
#      48   49    50    51   52   53  54  Cluster
# 1    39   10    34    30   36   26  29      2.0
# 2     3    2    -2     4    7   17   0      1.0
# 3    19   10     0     0   11    5   1      2.0
# 4   966  384  1017  1270  623  511  47      2.0
# 5    17   32    31    53   56   35  52      2.0
# 6    43   57    63    51   50   40  64      2.0
# 7     0    0     0     4   19    3   9      2.0
# 8    17   22    16    47   45   30   7      2.0
# 9     2    3     0     1    2    1   5      2.0
# 10    5    0     0    20    0    0   0      2.0
# 11   65  110    41    26   90   61  57      1.0
# 12   19    3    14    10   14    9  10      1.0
# 13    0    0     0    13    9   15  12      1.0
# 14   24   29    22    36    1   21   3      2.0
# 15   47   25    13     8    2    0  15      1.0
# 16  103   93   110   287   57   12  20      2.0
# 17    5   -5    15     0    0    0   0      2.0
#
# [17 rows x 56 columns]

# %%
data_test
# Out:
#    KODE PRODUK   53  54    55   56    57   58   59  60  Cluster
# 1        04073   26  29     8   19    57   10    2  20      2.0
# 2        18051   17   0     0    4    16    9    8   4      1.0
# 3        04176    5   1     3   13    12    1    4   0      2.0
# 4        18085  511  47  1079  302  1596    9  114  28      2.0
# 5        04177   35  52    45   87    16   28   22  15      2.0
# 6        04125   40  64    62  112    48   41   34  54      2.0
# 7        04132    3   9     3   10    22    5    0   0      2.0
# 8        04167   30   7    26   50    40   43   40  46      2.0
# 9        04148    1   5     1    4     0    0   11 -11      2.0
# 10       04043    0   0     0    0     0    0    0   0      2.0
# 11       04149   61  57    48   76    82   24   30  -1      1.0
# 12       04040    9  10     8    9     6    8    7   4      1.0
# 13       18071   15  12     0   18    29    6   18  10      1.0
# 14       04050   21   3    27    1    20   42    6  40      2.0
# 15       18074    0  15    38   35    10   28   25  49      1.0
# 16       18054   12  20    39   79    91  119  112  25      2.0
# 17       E1054    0   0     0    0     0    0    0   0      2.0

# %% [markdown]
# Make sure ada berapa cluster?

# %%
len(data['Cluster'].unique())
# Out:
# 2

# %% [markdown]
# Ambil jumlah produk dalam cluster ada berapa

# %%
#now lets take clusters
c1 = data.query("Cluster == 1")
print("Jumlah Produk:")
print(c1['KODE PRODUK'].size)
c2 = data.query("Cluster == 2")
print("Jumlah Produk:")
print(c2['KODE PRODUK'].size)
# Out:
# Jumlah Produk:
# 5
# Jumlah Produk:
# 12

# %%
c1_t = data_test.query("Cluster == 1")
print("Jumlah Produk:")
print(c1['KODE PRODUK'].size)
c2_t = data_test.query("Cluster == 2")
print("Jumlah Produk:")
print(c2['KODE PRODUK'].size)
# Out:
# Jumlah Produk:
# 5
# Jumlah Produk:
# 12

# %% [markdown]
# ## Pembuatan model cluster 1

# %% [markdown]
# Buat fungsi bikin `windowed dataset` jadi si data di couple in sama waktu (timeframe)

# %%
#oke ada ternyata yang cuman sendirian (1 product di cluster tersebut), kita beresin dia dulu, the easiest, dan biar keliatan kita
#ngapain aja di time series ini
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    series = tf.expand_dims(series, axis=-1)
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    ds = ds.shuffle(shuffle_buffer)
    ds = ds.map(lambda w: (w[:-1], w[1:]))
    return ds.batch(batch_size).prefetch(1)
# ini fungsinya buat nge ubah dataset jadi windowed

# %%
def time_data(data, window):
  x = []
  y = []
  for i in range(len(data)-window):
    x.append(data[i:(i+window)])
    y.append(data[i+window])
  return np.array(x),np.array(y)

# %% [markdown]
# ubah tipe data dari kode barang menjadi nilai angka

# %%
col = c1['KODE PRODUK'].values

# %%
#next kita ubah bentuk data nya dari yang tadinya kesamping jadi ke bawah, tapi pertama mau aku drop dulu cluster sama kode produknya
c1=c1.drop(columns=['KODE PRODUK','Cluster'])
c1_t=c1_t.drop(columns=['KODE PRODUK','Cluster'])

# %% [markdown]
# Plot per produk cluster 1

# %%
c1.set_index(col,inplace=True)
c1_t.set_index(col,inplace=True)
c1.T.plot()
# Out:
# <AxesSubplot:>

# %%
#Ambil satu sample dari cluster 1
# c1 = c1.sample()

# %%
# c1.T.plot()
#Kode 04146 hasilnya sangat bagus

# %%
#next, buat dia kayak mejeneng time series seperti biasanya, which is datanya ke bawah, tapi di average per tanggal 
new_c1=[]
time=[]
for idx,a in enumerate(c1):
    new_c1.append(c1[a].mean())
    time.append(idx)

# %%
#sama aja cuman data test
new_c1_t=[]
time_t=[]
i = 53
for idx,a in enumerate(c1_t):
    new_c1_t.append(c1_t[a].mean())
    time_t.append(i)
    i+=1

# %%
#normalisasi, karena gap nya ada yang sampe ribuan, biar lebih gampang tugas ann nya
series=np.array(new_c1)
series_t = np.array(new_c1_t)
# min = np.min(series)
# max = np.max(series)
# series = series - min
# series = series / (max-min)
time = np.array(time)
time_t = np.array(time_t)

# %%
# split_time = 6 # ini berapa bulan terkahir yang mau di potong buat pengujian?

time_train = time
x_train =  series
time_valid =  time_t
x_valid =  series_t

# %%
#check inputan dari data train seberapa banyak, 54 bulan kan?
len(x_train)
# Out:
# 54

# %%
len(x_valid)
# Out:
# 8

# %%
#buat data biar dibagi per window, jadi me masang masangkan waktu dan value,
window_size = 2
batch_size = 2
shuffle_buffer_size = 10

train_x, train_y = time_data(x_train, window_size)
valid_x, valid_y = time_data(x_valid, window_size)
# train_set = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)
# valid_set = windowed_dataset(x_valid, window_size, batch_size, shuffle_buffer_size)

# %%
#cek tipe data (isi) dari train set
train_x.shape
# Out:
# (52, 2)

# %%
#sama cuman data test, pastikan keduanya sama
valid_x.shape
# Out:
# (6, 2)

# %%
print(tf.__version__)
# Out:
# 2.9.1

# %%
from tensorflow.keras.callbacks import  EarlyStopping
callbacks = EarlyStopping(
    min_delta=0.000001,
    
    patience=100,
    restore_best_weights=True,
)

# %%
len(train_x[0])
# Out:
# 2

# %% [markdown]
# Penyusunan deep learning nya
#
# Kita Menggunakan BLSTM atau *Bidirectional Long Short Term Memory*. BLSTM adalah proses pembuatan jaringan syaraf tiruan untuk memiliki urutan informasi dalam kedua arah mundur (masa depan ke masa lalu) atau maju (masa lalu ke masa depan).
#
#
# kalo ini pake BLSTM dengan input layer sebanyak 10 neuron, BLSTM layer ada dua, yang pertama ada 64 neuron, terus yang kedua ada 32 neuron, dibuat mengkerucut (segitiga terbalik) seolah kita menyederhanakan data datanya, jadi kan makin dalem makin sedikit tuh, karena ada yang ga kepake kepake buat menentukan sales nya dan lain lain,
#
# terus setiap selesai masuk BLSTM layer, ada dropout, itu tuh untuk mengeliminasi secara random (di case ini 50%) sambungan antara neuron, dan nge "matiin" neuronnya itu juga, mensimulasi degradasi neuron dan sambungannya saat kita tidur, alias proses mengubah ingatan jadi jangka menengah ke panjang dari apa yang kita dapatkan pada hari itu.

# %%
model = tf.keras.Sequential([
        tf.keras.layers.Dense(10, input_shape=[len(train_x[0]), 1]),
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128,return_sequences=True)),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
        # tf.keras.layers.Dropout(0.5),
        # tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(8,return_sequences=True)),
        # tf.keras.layers.Dropout(0.9),
        
        
        # tf.keras.layers.Flatten(),
        # tf.keras.layers.Dense(1024, activation='relu'),
        # tf.keras.layers.Dropout(0.5),
        # tf.keras.layers.Dense(512, activation='relu',kernel_regularizer=tf.keras.regularizers.l1(l1=0.01)),
        # tf.keras.layers.Dense(64, activation='relu',kernel_regularizer=tf.keras.regularizers.l1_l2(l1=0.01, l2=0.01)),
        # tf.keras.layers.Dense(32, activation='relu'),
        # tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(1, activation='relu')
    ])

    #the blstm part

# %%
# The model Below  successfully achieves a MSE of 0.1 on the validation set and the result is really good.
# model = tf.keras.Sequential([
#         tf.keras.layers.Dense(2, input_shape=[None, 1]),
        
#         tf.keras.layers.LSTM(512,return_sequences=True),
#         tf.keras.layers.LSTM(128),
        
#         # tf.keras.layers.Flatten(),
#         # tf.keras.layers.Dense(1024, activation='relu'),
#         # tf.keras.layers.Dropout(0.5),
#         # tf.keras.layers.Dense(512, activation='relu',kernel_regularizer=tf.keras.regularizers.l1(l1=0.01)),
#         # tf.keras.layers.Dense(64, activation='relu',kernel_regularizer=tf.keras.regularizers.l1_l2(l1=0.01, l2=0.01)),
#         # tf.keras.layers.Dense(32, activation='relu'),
#         # tf.keras.layers.Dropout(0.3),
#         tf.keras.layers.Dense(1, activation='relu')
#     ])

# %%
#Training, pake model.fit()
#Using mae and mse
#model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9),metrics=['mae'],loss='mse')
#optimizers itu buat memilih fungsi optimasi, jadi itu sebuah fungsi yang bertanggung jawab biar tiap epoch itu ada perubahan yang baik
#dengan cara membuat per layer belajar nya lebih keras atau lebih ringan, dengan cara mengubah parameter dari tiap layer
#secara matematis, si optimizer akan berusaha mencari loss terkecil dalam distribusi loss dibanding parameter
model.compile(optimizer=tf.keras.optimizers.Adam(),metrics=['mae'],loss='mse')
model.summary()
hist=model.fit(train_x,train_y,epochs=1000,validation_data=(valid_x,valid_y), batch_size=1,callbacks=[callbacks])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 2, 10)             20
#
#  bidirectional (Bidirectiona  (None, 2, 256)           142336
#  l)
#
#  dropout (Dropout)           (None, 2, 256)            0
#
#  bidirectional_1 (Bidirectio  (None, 64)               73984
#  nal)
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 216,405
# Trainable params: 216,405
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 52/52 [==============================] - 8s 41ms/step - loss: 6088.7217 - mae: 65.5308 - val_loss: 447.8267 - val_mae: 20.2667
# Epoch 2/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 6088.7197 - mae: 65.5308 - val_loss: 447.8267 - val_mae: 20.2667
# Epoch 3/1000
# 52/52 [==============================] - 0s 5ms/step - loss: 6088.7217 - mae: 65.5308 - val_loss: 447.8267 - val_mae: 20.2667
# Epoch 4/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 6088.7217 - mae: 65.5308 - val_loss: 447.8267 - val_mae: 20.2667
# Epoch 5/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 6088.7207 - mae: 65.5308 - val_loss: 447.8267 - val_mae: 20.2667
# Epoch 6/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 5523.3091 - mae: 61.0434 - val_loss: 98.1355 - val_mae: 7.8139
# Epoch 7/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 4250.3784 - mae: 50.2925 - val_loss: 38.7193 - val_mae: 5.0624
# Epoch 8/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 3770.2903 - mae: 46.3855 - val_loss: 46.0882 - val_mae: 6.4889
# Epoch 9/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 3448.8350 - mae: 44.0149 - val_loss: 75.9567 - val_mae: 7.5669
# Epoch 10/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 3203.3462 - mae: 42.5188 - val_loss: 122.8799 - val_mae: 9.2626
# Epoch 11/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 3000.8389 - mae: 41.2645 - val_loss: 176.8075 - val_mae: 11.8209
# Epoch 12/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 2836.6562 - mae: 40.3087 - val_loss: 231.6122 - val_mae: 13.9545
# Epoch 13/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 2682.3906 - mae: 38.8300 - val_loss: 193.8525 - val_mae: 12.6369
# Epoch 14/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 2509.3542 - mae: 36.5784 - val_loss: 59.8494 - val_mae: 5.4014
# Epoch 15/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 2379.2881 - mae: 35.3076 - val_loss: 49.6323 - val_mae: 5.5453
# Epoch 16/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 2232.6733 - mae: 33.6247 - val_loss: 48.2472 - val_mae: 4.9859
# Epoch 17/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 2114.5400 - mae: 32.2334 - val_loss: 42.5315 - val_mae: 5.0740
# Epoch 18/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 2014.6600 - mae: 31.3075 - val_loss: 35.7438 - val_mae: 5.2635
# Epoch 19/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 1908.7155 - mae: 29.8171 - val_loss: 42.1253 - val_mae: 5.7015
# Epoch 20/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 1829.0717 - mae: 29.4523 - val_loss: 36.6664 - val_mae: 5.5250
# Epoch 21/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 1742.4344 - mae: 28.1299 - val_loss: 45.2910 - val_mae: 6.0846
# Epoch 22/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 1676.9146 - mae: 27.7353 - val_loss: 39.3689 - val_mae: 5.9228
# Epoch 23/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 1610.3077 - mae: 27.0697 - val_loss: 76.7503 - val_mae: 6.7974
# Epoch 24/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 1548.0718 - mae: 26.3936 - val_loss: 43.0303 - val_mae: 5.8888
# Epoch 25/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 1486.8618 - mae: 25.6193 - val_loss: 49.6182 - val_mae: 6.0160
# Epoch 26/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 1433.3917 - mae: 24.8705 - val_loss: 39.8421 - val_mae: 5.9419
# Epoch 27/1000
# 52/52 [==============================] - 0s 6ms/step - loss: 1436.3861 - mae: 26.0765 - val_loss: 49.7358 - val_mae: 6.3174
# Epoch 28/1000
# 52/52 [==============================] - 0s 5ms/step - loss: 1334.3887 - mae: 23.8909 - val_loss: 81.4132 - val_mae: 7.2283
# Epoch 29/1000
# 52/52 [==============================] - 0s 5ms/step - loss: 1314.7798 - mae: 24.2743 - val_loss: 43.0720 - val_mae: 6.3083
# Epoch 30/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 1288.6050 - mae: 24.2811 - val_loss: 93.7469 - val_mae: 7.7830
# Epoch 31/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 1254.2708 - mae: 24.0394 - val_loss: 82.6882 - val_mae: 7.2455
# Epoch 32/1000
# 52/52 [==============================] - 0s 5ms/step - loss: 1207.0255 - mae: 23.4494 - val_loss: 48.6947 - val_mae: 6.3932
# Epoch 33/1000
# 52/52 [==============================] - 0s 5ms/step - loss: 1169.4205 - mae: 23.1504 - val_loss: 54.4593 - val_mae: 6.6749
# Epoch 34/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 1138.5946 - mae: 22.6136 - val_loss: 44.9538 - val_mae: 6.4571
# Epoch 35/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 1114.8311 - mae: 22.7481 - val_loss: 49.1690 - val_mae: 6.5447
# Epoch 36/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 1072.4246 - mae: 21.4756 - val_loss: 43.0919 - val_mae: 6.3211
# Epoch 37/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 1088.5002 - mae: 22.8133 - val_loss: 47.7496 - val_mae: 6.4561
# Epoch 38/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 1027.0907 - mae: 21.8285 - val_loss: 39.0410 - val_mae: 5.9147
# Epoch 39/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 1036.3523 - mae: 21.7733 - val_loss: 53.2276 - val_mae: 6.6195
# Epoch 40/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 996.2545 - mae: 21.5201 - val_loss: 48.0606 - val_mae: 6.2589
# Epoch 41/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 945.7444 - mae: 20.6598 - val_loss: 40.6300 - val_mae: 5.1378
# Epoch 42/1000
# 52/52 [==============================] - 0s 5ms/step - loss: 937.1075 - mae: 20.7823 - val_loss: 39.0512 - val_mae: 5.1956
# Epoch 43/1000
# 52/52 [==============================] - 0s 5ms/step - loss: 961.8614 - mae: 21.6200 - val_loss: 36.0855 - val_mae: 5.0087
# Epoch 44/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 914.6952 - mae: 20.3296 - val_loss: 39.1188 - val_mae: 5.6631
# Epoch 45/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 890.6272 - mae: 20.6427 - val_loss: 52.7947 - val_mae: 6.4313
# Epoch 46/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 903.1112 - mae: 20.7957 - val_loss: 37.8270 - val_mae: 5.3072
# Epoch 47/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 902.3804 - mae: 20.7437 - val_loss: 35.9902 - val_mae: 5.3179
# Epoch 48/1000
# 52/52 [==============================] - 0s 3ms/step - loss: 900.8102 - mae: 21.2374 - val_loss: 76.0209 - val_mae: 6.9690
# Epoch 49/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 814.8212 - mae: 19.4995 - val_loss: 37.0989 - val_mae: 5.2339
# Epoch 50/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 811.8074 - mae: 19.1721 - val_loss: 37.2126 - val_mae: 5.6443
# Epoch 51/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 826.3779 - mae: 19.7096 - val_loss: 39.1188 - val_mae: 5.8381
# Epoch 52/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 800.1603 - mae: 19.3902 - val_loss: 36.8991 - val_mae: 5.4137
# Epoch 53/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 735.9145 - mae: 18.3309 - val_loss: 34.6745 - val_mae: 4.7390
# Epoch 54/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 758.5680 - mae: 18.3199 - val_loss: 47.4985 - val_mae: 5.7068
# Epoch 55/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 727.8409 - mae: 18.4084 - val_loss: 35.8880 - val_mae: 4.9180
# Epoch 56/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 808.4928 - mae: 19.0584 - val_loss: 35.7199 - val_mae: 5.1516
# Epoch 57/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 741.2736 - mae: 18.6131 - val_loss: 33.5195 - val_mae: 4.8874
# Epoch 58/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 737.0123 - mae: 18.9961 - val_loss: 44.6302 - val_mae: 5.6127
# Epoch 59/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 689.4567 - mae: 17.4697 - val_loss: 34.9816 - val_mae: 5.0983
# Epoch 60/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 686.6943 - mae: 17.5846 - val_loss: 35.0302 - val_mae: 4.9953
# Epoch 61/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 719.4845 - mae: 17.7875 - val_loss: 55.3380 - val_mae: 6.3779
# Epoch 62/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 811.0485 - mae: 19.8762 - val_loss: 35.4418 - val_mae: 5.1673
# Epoch 63/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 629.4077 - mae: 16.4385 - val_loss: 35.9061 - val_mae: 5.3799
# Epoch 64/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 700.1946 - mae: 17.0216 - val_loss: 34.8554 - val_mae: 5.2197
# Epoch 65/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 723.9286 - mae: 18.4226 - val_loss: 36.4606 - val_mae: 5.4484
# Epoch 66/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 681.6077 - mae: 17.3775 - val_loss: 34.5686 - val_mae: 5.2105
# Epoch 67/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 698.2675 - mae: 16.9738 - val_loss: 34.0556 - val_mae: 5.2114
# Epoch 68/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 598.4263 - mae: 16.4912 - val_loss: 35.8816 - val_mae: 5.3642
# Epoch 69/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 570.7936 - mae: 15.8292 - val_loss: 34.8109 - val_mae: 5.2255
# Epoch 70/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 577.9617 - mae: 16.1489 - val_loss: 35.3215 - val_mae: 5.3509
# Epoch 71/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 602.4825 - mae: 16.0867 - val_loss: 36.1461 - val_mae: 5.4548
# Epoch 72/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 602.6549 - mae: 16.2593 - val_loss: 34.8736 - val_mae: 5.1629
# Epoch 73/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 582.0488 - mae: 16.3901 - val_loss: 37.7090 - val_mae: 5.4940
# Epoch 74/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 595.4519 - mae: 16.4212 - val_loss: 35.1854 - val_mae: 5.2923
# Epoch 75/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 553.0551 - mae: 15.7474 - val_loss: 36.4436 - val_mae: 5.4335
# Epoch 76/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 546.2310 - mae: 15.3610 - val_loss: 36.3061 - val_mae: 5.3596
# Epoch 77/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 559.1805 - mae: 15.4706 - val_loss: 34.8229 - val_mae: 5.2766
# Epoch 78/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 536.8435 - mae: 15.2094 - val_loss: 36.1663 - val_mae: 5.4682
# Epoch 79/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 560.6591 - mae: 15.3213 - val_loss: 35.9130 - val_mae: 5.3732
# Epoch 80/1000
# 52/52 [==============================] - 0s 5ms/step - loss: 562.2637 - mae: 15.8346 - val_loss: 42.4396 - val_mae: 5.8600
# Epoch 81/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 502.5288 - mae: 15.3390 - val_loss: 35.1584 - val_mae: 5.1660
# Epoch 82/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 599.4333 - mae: 16.2955 - val_loss: 36.4145 - val_mae: 5.2097
# Epoch 83/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 542.2418 - mae: 15.4874 - val_loss: 36.5429 - val_mae: 5.0387
# Epoch 84/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 495.1042 - mae: 14.7107 - val_loss: 36.6311 - val_mae: 5.5303
# Epoch 85/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 523.5128 - mae: 14.9628 - val_loss: 44.3389 - val_mae: 5.8509
# Epoch 86/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 531.3851 - mae: 15.2010 - val_loss: 47.2612 - val_mae: 5.7802
# Epoch 87/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 502.2828 - mae: 14.7926 - val_loss: 34.5493 - val_mae: 5.1788
# Epoch 88/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 461.1126 - mae: 14.0438 - val_loss: 45.0298 - val_mae: 5.2488
# Epoch 89/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 458.6545 - mae: 13.8980 - val_loss: 38.8666 - val_mae: 4.9787
# Epoch 90/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 503.8779 - mae: 14.0958 - val_loss: 33.6995 - val_mae: 4.9364
# Epoch 91/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 477.7811 - mae: 14.5132 - val_loss: 39.6796 - val_mae: 5.3209
# Epoch 92/1000
# 52/52 [==============================] - 0s 3ms/step - loss: 533.9755 - mae: 15.2121 - val_loss: 38.9620 - val_mae: 5.0522
# Epoch 93/1000
# 52/52 [==============================] - 0s 3ms/step - loss: 456.4204 - mae: 13.8824 - val_loss: 38.2987 - val_mae: 5.3409
# Epoch 94/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 467.1165 - mae: 14.4128 - val_loss: 33.9479 - val_mae: 4.7975
# Epoch 95/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 499.7656 - mae: 13.7091 - val_loss: 35.1503 - val_mae: 5.1358
# Epoch 96/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 476.2056 - mae: 14.1348 - val_loss: 34.4273 - val_mae: 4.8503
# Epoch 97/1000
# 52/52 [==============================] - 0s 3ms/step - loss: 534.8695 - mae: 15.1680 - val_loss: 34.2223 - val_mae: 4.9791
# Epoch 98/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 449.7510 - mae: 13.8238 - val_loss: 37.1700 - val_mae: 5.3365
# Epoch 99/1000
# 52/52 [==============================] - 0s 3ms/step - loss: 422.8083 - mae: 13.2819 - val_loss: 34.9998 - val_mae: 4.7904
# Epoch 100/1000
# 52/52 [==============================] - 0s 3ms/step - loss: 509.9712 - mae: 15.1889 - val_loss: 35.4940 - val_mae: 5.1845
# Epoch 101/1000
# 52/52 [==============================] - 0s 3ms/step - loss: 435.8991 - mae: 13.0598 - val_loss: 36.6280 - val_mae: 5.1954
# Epoch 102/1000
# 52/52 [==============================] - 0s 3ms/step - loss: 458.1558 - mae: 13.6664 - val_loss: 34.6661 - val_mae: 5.0633
# Epoch 103/1000
# 52/52 [==============================] - 0s 3ms/step - loss: 520.7953 - mae: 15.4388 - val_loss: 53.4439 - val_mae: 5.9221
# Epoch 104/1000
# 52/52 [==============================] - 0s 3ms/step - loss: 540.4712 - mae: 15.3818 - val_loss: 38.2476 - val_mae: 5.2260
# Epoch 105/1000
# 52/52 [==============================] - 0s 3ms/step - loss: 472.0804 - mae: 13.8292 - val_loss: 34.0931 - val_mae: 4.9058
# Epoch 106/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 535.2128 - mae: 14.1047 - val_loss: 33.3371 - val_mae: 4.8689
# Epoch 107/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 465.7396 - mae: 14.6768 - val_loss: 34.3374 - val_mae: 4.9072
# Epoch 108/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 477.7282 - mae: 14.6362 - val_loss: 36.0326 - val_mae: 4.9525
# Epoch 109/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 425.8965 - mae: 13.8988 - val_loss: 37.0226 - val_mae: 5.1077
# Epoch 110/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 455.0073 - mae: 13.1042 - val_loss: 36.1336 - val_mae: 4.9333
# Epoch 111/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 389.0776 - mae: 13.3767 - val_loss: 33.8137 - val_mae: 4.8604
# Epoch 112/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 505.0953 - mae: 15.1972 - val_loss: 35.3421 - val_mae: 5.0243
# Epoch 113/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 424.1591 - mae: 13.0346 - val_loss: 40.8099 - val_mae: 5.1510
# Epoch 114/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 525.5007 - mae: 15.5478 - val_loss: 35.5057 - val_mae: 5.2872
# Epoch 115/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 418.9688 - mae: 13.0756 - val_loss: 38.4412 - val_mae: 5.3697
# Epoch 116/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 436.6443 - mae: 13.4908 - val_loss: 31.2218 - val_mae: 4.8287
# Epoch 117/1000
# 52/52 [==============================] - 0s 5ms/step - loss: 461.3089 - mae: 12.7566 - val_loss: 30.3480 - val_mae: 4.7686
# Epoch 118/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 447.7900 - mae: 13.5327 - val_loss: 32.3427 - val_mae: 4.9650
# Epoch 119/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 447.3302 - mae: 13.9288 - val_loss: 32.0855 - val_mae: 4.9810
# Epoch 120/1000
# 52/52 [==============================] - 0s 3ms/step - loss: 439.9434 - mae: 13.4832 - val_loss: 30.3445 - val_mae: 4.7528
# Epoch 121/1000
# 52/52 [==============================] - 0s 3ms/step - loss: 393.7673 - mae: 12.3557 - val_loss: 29.1629 - val_mae: 4.6550
# Epoch 122/1000
# 52/52 [==============================] - 0s 3ms/step - loss: 384.7420 - mae: 13.0979 - val_loss: 35.5925 - val_mae: 5.1651
# Epoch 123/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 522.0000 - mae: 14.5759 - val_loss: 29.4144 - val_mae: 4.9623
# Epoch 124/1000
# 52/52 [==============================] - 0s 3ms/step - loss: 419.2566 - mae: 12.9969 - val_loss: 31.8454 - val_mae: 4.7451
# Epoch 125/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 478.4478 - mae: 14.1768 - val_loss: 33.9783 - val_mae: 5.1513
# Epoch 126/1000
# 52/52 [==============================] - 0s 3ms/step - loss: 413.0124 - mae: 12.9223 - val_loss: 34.6256 - val_mae: 4.9622
# Epoch 127/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 480.8855 - mae: 13.9472 - val_loss: 35.7351 - val_mae: 5.2347
# Epoch 128/1000
# 52/52 [==============================] - 0s 3ms/step - loss: 424.7191 - mae: 12.9368 - val_loss: 35.8832 - val_mae: 5.3818
# Epoch 129/1000
# 52/52 [==============================] - 0s 3ms/step - loss: 488.8114 - mae: 15.0720 - val_loss: 33.3456 - val_mae: 5.1233
# Epoch 130/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 396.4794 - mae: 12.9671 - val_loss: 38.9328 - val_mae: 5.3637
# Epoch 131/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 424.2830 - mae: 13.0901 - val_loss: 39.6374 - val_mae: 5.2852
# Epoch 132/1000
# 52/52 [==============================] - 0s 3ms/step - loss: 333.4797 - mae: 11.7150 - val_loss: 29.6618 - val_mae: 4.7932
# Epoch 133/1000
# 52/52 [==============================] - 0s 3ms/step - loss: 372.7029 - mae: 12.8085 - val_loss: 29.2701 - val_mae: 4.7047
# Epoch 134/1000
# 52/52 [==============================] - 0s 3ms/step - loss: 476.1724 - mae: 14.1946 - val_loss: 29.0566 - val_mae: 4.6089
# Epoch 135/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 424.7064 - mae: 13.7748 - val_loss: 35.8249 - val_mae: 5.1964
# Epoch 136/1000
# 52/52 [==============================] - 0s 3ms/step - loss: 447.1514 - mae: 14.1151 - val_loss: 30.6257 - val_mae: 4.7041
# Epoch 137/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 447.5743 - mae: 14.4249 - val_loss: 33.3215 - val_mae: 4.9382
# Epoch 138/1000
# 52/52 [==============================] - 0s 3ms/step - loss: 426.2093 - mae: 13.1094 - val_loss: 33.4126 - val_mae: 5.0484
# Epoch 139/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 443.7648 - mae: 13.8935 - val_loss: 31.3268 - val_mae: 4.9574
# Epoch 140/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 387.9760 - mae: 12.8320 - val_loss: 30.3517 - val_mae: 4.9251
# Epoch 141/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 452.6774 - mae: 13.7988 - val_loss: 37.6617 - val_mae: 5.3507
# Epoch 142/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 370.6007 - mae: 12.8679 - val_loss: 31.9222 - val_mae: 4.7887
# Epoch 143/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 457.8244 - mae: 13.7219 - val_loss: 31.8699 - val_mae: 5.0212
# Epoch 144/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 409.9710 - mae: 13.3542 - val_loss: 31.1287 - val_mae: 4.8405
# Epoch 145/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 417.0635 - mae: 13.1724 - val_loss: 35.4315 - val_mae: 5.1827
# Epoch 146/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 460.0981 - mae: 13.7405 - val_loss: 38.2850 - val_mae: 5.4353
# Epoch 147/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 409.8702 - mae: 13.2159 - val_loss: 33.7704 - val_mae: 4.9207
# Epoch 148/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 387.6323 - mae: 12.7075 - val_loss: 34.6030 - val_mae: 5.0343
# Epoch 149/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 453.4690 - mae: 12.6243 - val_loss: 35.0550 - val_mae: 4.9822
# Epoch 150/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 408.5108 - mae: 12.2364 - val_loss: 34.3184 - val_mae: 4.9477
# Epoch 151/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 398.4810 - mae: 14.3091 - val_loss: 31.7345 - val_mae: 4.8585
# Epoch 152/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 424.9072 - mae: 12.9983 - val_loss: 32.0948 - val_mae: 4.9996
# Epoch 153/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 481.7819 - mae: 13.4444 - val_loss: 32.2220 - val_mae: 5.1211
# Epoch 154/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 473.9625 - mae: 13.7620 - val_loss: 30.8912 - val_mae: 4.9410
# Epoch 155/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 371.3840 - mae: 12.6532 - val_loss: 34.8785 - val_mae: 5.1760
# Epoch 156/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 458.2088 - mae: 15.0163 - val_loss: 32.1613 - val_mae: 4.9865
# Epoch 157/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 372.5610 - mae: 13.1586 - val_loss: 31.6374 - val_mae: 5.0238
# Epoch 158/1000
# 52/52 [==============================] - 0s 3ms/step - loss: 387.8936 - mae: 13.0390 - val_loss: 32.4393 - val_mae: 5.1833
# Epoch 159/1000
# 52/52 [==============================] - 0s 3ms/step - loss: 389.3348 - mae: 12.5018 - val_loss: 30.9933 - val_mae: 4.9698
# Epoch 160/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 397.7128 - mae: 13.1785 - val_loss: 31.8620 - val_mae: 5.1255
# Epoch 161/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 415.6721 - mae: 12.0742 - val_loss: 31.7569 - val_mae: 5.0667
# Epoch 162/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 391.1592 - mae: 12.4735 - val_loss: 59.7353 - val_mae: 6.0697
# Epoch 163/1000
# 52/52 [==============================] - 0s 3ms/step - loss: 350.0695 - mae: 11.2432 - val_loss: 54.9673 - val_mae: 6.1413
# Epoch 164/1000
# 52/52 [==============================] - 0s 3ms/step - loss: 423.3388 - mae: 13.3609 - val_loss: 48.6030 - val_mae: 5.9936
# Epoch 165/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 379.5435 - mae: 12.6890 - val_loss: 34.4969 - val_mae: 4.9914
# Epoch 166/1000
# 52/52 [==============================] - 0s 3ms/step - loss: 354.8686 - mae: 12.2017 - val_loss: 36.1209 - val_mae: 5.4095
# Epoch 167/1000
# 52/52 [==============================] - 0s 3ms/step - loss: 395.4380 - mae: 14.3174 - val_loss: 39.3606 - val_mae: 5.6764
# Epoch 168/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 412.3860 - mae: 12.7081 - val_loss: 43.4386 - val_mae: 5.9212
# Epoch 169/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 430.8173 - mae: 13.5783 - val_loss: 31.8582 - val_mae: 4.9834
# Epoch 170/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 384.5948 - mae: 12.7030 - val_loss: 31.8503 - val_mae: 5.0277
# Epoch 171/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 399.4473 - mae: 12.2902 - val_loss: 32.2512 - val_mae: 5.0824
# Epoch 172/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 426.2514 - mae: 13.3161 - val_loss: 32.5278 - val_mae: 5.0956
# Epoch 173/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 334.5461 - mae: 12.3502 - val_loss: 35.8652 - val_mae: 5.3845
# Epoch 174/1000
# 52/52 [==============================] - 0s 5ms/step - loss: 420.3811 - mae: 13.5513 - val_loss: 38.1696 - val_mae: 5.5461
# Epoch 175/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 410.6859 - mae: 13.2576 - val_loss: 40.6255 - val_mae: 5.5120
# Epoch 176/1000
# 52/52 [==============================] - 0s 3ms/step - loss: 429.0040 - mae: 12.9620 - val_loss: 41.6101 - val_mae: 5.5181
# Epoch 177/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 396.9843 - mae: 12.7737 - val_loss: 37.3209 - val_mae: 5.3238
# Epoch 178/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 392.1862 - mae: 12.5134 - val_loss: 32.4006 - val_mae: 4.9385
# Epoch 179/1000
# 52/52 [==============================] - 0s 5ms/step - loss: 390.1587 - mae: 13.1934 - val_loss: 32.2447 - val_mae: 4.9656
# Epoch 180/1000
# 52/52 [==============================] - 0s 5ms/step - loss: 358.6110 - mae: 12.0065 - val_loss: 33.6306 - val_mae: 5.0896
# Epoch 181/1000
# 52/52 [==============================] - 0s 5ms/step - loss: 373.3521 - mae: 12.5630 - val_loss: 32.3778 - val_mae: 4.9245
# Epoch 182/1000
# 52/52 [==============================] - 0s 6ms/step - loss: 416.1201 - mae: 13.4620 - val_loss: 38.5146 - val_mae: 5.3449
# Epoch 183/1000
# 52/52 [==============================] - 0s 5ms/step - loss: 366.6118 - mae: 12.4065 - val_loss: 37.4323 - val_mae: 5.0559
# Epoch 184/1000
# 52/52 [==============================] - 0s 5ms/step - loss: 313.6263 - mae: 10.9560 - val_loss: 33.6462 - val_mae: 4.9460
# Epoch 185/1000
# 52/52 [==============================] - 0s 5ms/step - loss: 346.6389 - mae: 12.0581 - val_loss: 30.3646 - val_mae: 4.6652
# Epoch 186/1000
# 52/52 [==============================] - 0s 5ms/step - loss: 437.3057 - mae: 12.5417 - val_loss: 33.5817 - val_mae: 5.0585
# Epoch 187/1000
# 52/52 [==============================] - 0s 5ms/step - loss: 365.3664 - mae: 11.7335 - val_loss: 34.8415 - val_mae: 4.8723
# Epoch 188/1000
# 52/52 [==============================] - 0s 5ms/step - loss: 435.6126 - mae: 12.9182 - val_loss: 35.7892 - val_mae: 5.2406
# Epoch 189/1000
# 52/52 [==============================] - 0s 8ms/step - loss: 376.0525 - mae: 12.0493 - val_loss: 31.5557 - val_mae: 4.7998
# Epoch 190/1000
# 52/52 [==============================] - 0s 5ms/step - loss: 423.7901 - mae: 13.2142 - val_loss: 52.1604 - val_mae: 5.9824
# Epoch 191/1000
# 52/52 [==============================] - 0s 7ms/step - loss: 413.9659 - mae: 11.8800 - val_loss: 32.1717 - val_mae: 4.8785
# Epoch 192/1000
# 52/52 [==============================] - 0s 3ms/step - loss: 422.1064 - mae: 13.6970 - val_loss: 37.4350 - val_mae: 5.3993
# Epoch 193/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 396.7670 - mae: 12.6021 - val_loss: 34.4321 - val_mae: 5.1247
# Epoch 194/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 317.2902 - mae: 11.4630 - val_loss: 30.9193 - val_mae: 4.7792
# Epoch 195/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 400.9558 - mae: 12.4440 - val_loss: 32.7606 - val_mae: 5.0825
# Epoch 196/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 313.5764 - mae: 11.4218 - val_loss: 31.4256 - val_mae: 4.8611
# Epoch 197/1000
# 52/52 [==============================] - 0s 6ms/step - loss: 395.9250 - mae: 12.5708 - val_loss: 37.1998 - val_mae: 5.4072
# Epoch 198/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 370.0702 - mae: 12.8666 - val_loss: 33.2941 - val_mae: 5.0454
# Epoch 199/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 341.9935 - mae: 12.0803 - val_loss: 30.8104 - val_mae: 4.7987
# Epoch 200/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 418.3809 - mae: 13.0560 - val_loss: 33.5332 - val_mae: 5.0070
# Epoch 201/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 333.9487 - mae: 11.3261 - val_loss: 33.1310 - val_mae: 5.1065
# Epoch 202/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 365.7248 - mae: 11.8969 - val_loss: 35.7670 - val_mae: 5.3377
# Epoch 203/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 336.7277 - mae: 11.4549 - val_loss: 35.4805 - val_mae: 5.3363
# Epoch 204/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 410.6833 - mae: 13.4971 - val_loss: 46.7535 - val_mae: 5.8495
# Epoch 205/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 324.3371 - mae: 11.2572 - val_loss: 35.9716 - val_mae: 5.4092
# Epoch 206/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 370.7017 - mae: 12.7265 - val_loss: 31.1637 - val_mae: 4.9386
# Epoch 207/1000
# 52/52 [==============================] - 0s 5ms/step - loss: 332.0371 - mae: 11.5654 - val_loss: 30.3803 - val_mae: 4.9104
# Epoch 208/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 429.8295 - mae: 13.3748 - val_loss: 32.3200 - val_mae: 5.1105
# Epoch 209/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 344.7322 - mae: 12.2170 - val_loss: 34.2364 - val_mae: 5.2961
# Epoch 210/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 400.0486 - mae: 13.0344 - val_loss: 30.7939 - val_mae: 4.9501
# Epoch 211/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 396.3432 - mae: 13.3712 - val_loss: 30.3493 - val_mae: 4.8281
# Epoch 212/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 365.6215 - mae: 12.3002 - val_loss: 32.4153 - val_mae: 4.9249
# Epoch 213/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 315.1559 - mae: 11.6279 - val_loss: 31.1787 - val_mae: 4.7548
# Epoch 214/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 351.5202 - mae: 11.5666 - val_loss: 32.1622 - val_mae: 4.7758
# Epoch 215/1000
# 52/52 [==============================] - 0s 5ms/step - loss: 369.8349 - mae: 12.5562 - val_loss: 34.1726 - val_mae: 4.9994
# Epoch 216/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 409.5444 - mae: 13.3311 - val_loss: 41.8972 - val_mae: 5.6186
# Epoch 217/1000
# 52/52 [==============================] - 0s 5ms/step - loss: 326.8130 - mae: 11.6505 - val_loss: 43.1199 - val_mae: 5.7048
# Epoch 218/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 350.1826 - mae: 11.9277 - val_loss: 30.5285 - val_mae: 4.6137
# Epoch 219/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 335.0161 - mae: 11.4420 - val_loss: 31.0301 - val_mae: 4.7139
# Epoch 220/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 354.6145 - mae: 11.6691 - val_loss: 36.4109 - val_mae: 5.2856
# Epoch 221/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 339.8600 - mae: 11.5166 - val_loss: 33.1595 - val_mae: 4.9257
# Epoch 222/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 362.9001 - mae: 12.2191 - val_loss: 42.8763 - val_mae: 5.6215
# Epoch 223/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 350.9317 - mae: 11.8840 - val_loss: 33.6146 - val_mae: 4.8041
# Epoch 224/1000
# 52/52 [==============================] - 0s 3ms/step - loss: 384.1033 - mae: 13.2364 - val_loss: 33.8167 - val_mae: 4.8358
# Epoch 225/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 332.2510 - mae: 11.7350 - val_loss: 32.8431 - val_mae: 4.9984
# Epoch 226/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 418.7863 - mae: 12.8689 - val_loss: 31.6502 - val_mae: 4.8668
# Epoch 227/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 318.7734 - mae: 10.9380 - val_loss: 30.2893 - val_mae: 4.7387
# Epoch 228/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 414.0287 - mae: 12.3050 - val_loss: 38.1404 - val_mae: 5.3092
# Epoch 229/1000
# 52/52 [==============================] - 0s 5ms/step - loss: 373.3821 - mae: 12.5867 - val_loss: 40.0930 - val_mae: 5.4872
# Epoch 230/1000
# 52/52 [==============================] - 0s 5ms/step - loss: 390.0301 - mae: 13.4346 - val_loss: 31.2594 - val_mae: 4.8896
# Epoch 231/1000
# 52/52 [==============================] - 0s 7ms/step - loss: 372.6092 - mae: 12.6850 - val_loss: 32.3988 - val_mae: 5.0118
# Epoch 232/1000
# 52/52 [==============================] - 0s 3ms/step - loss: 395.2350 - mae: 12.5397 - val_loss: 37.8948 - val_mae: 5.6750
# Epoch 233/1000
# 52/52 [==============================] - 0s 3ms/step - loss: 382.0555 - mae: 12.9017 - val_loss: 30.5290 - val_mae: 4.7060
# Epoch 234/1000
# 52/52 [==============================] - 0s 4ms/step - loss: 370.5117 - mae: 11.6990 - val_loss: 38.4608 - val_mae: 5.5883

# %%
import matplotlib.pyplot as plt
plt.plot(hist.history['mae'], label='MAE (training data)')
plt.plot(hist.history['val_mae'], label='MAE (validation data)')

plt.title("MAE Cluster 1")
plt.ylabel('MAE value')
plt.xlabel('No. epoch')
plt.legend(loc="upper left")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(hist.history['loss'], label='Loss (training data)')
plt.plot(hist.history['val_loss'], label='Loss (validation data)')

plt.title("Loss Cluster 1 (MSE)")
plt.ylabel('Loss value')
plt.xlabel('No. epoch')
plt.legend(loc="upper left")
plt.show()

# %%
valid_x
# Out:
# array([[20.4, 18.8],
#        [18.8, 18.8],
#        [18.8, 28.4],
#        [28.4, 28.6],
#        [28.6, 15. ],
#        [15. , 17.6]])

# %%
valid_y
# Out:
# array([18.8, 28.4, 28.6, 15. , 17.6, 13.2])

# %%
x_valid
# Out:
# array([20.4, 18.8, 18.8, 28.4, 28.6, 15. , 17.6, 13.2])

# %%
valid_x
# Out:
# array([[20.4, 18.8],
#        [18.8, 18.8],
#        [18.8, 28.4],
#        [28.4, 28.6],
#        [28.6, 15. ],
#        [15. , 17.6]])

# %%
prediksi=model.predict(valid_x)
prediksi
# Out:
# 1/1 [==============================] - 1s 1s/step
# array([[20.63807 ],
#        [21.896309],
#        [22.869663],
#        [18.302526],
#        [16.466526],
#        [22.345194]], dtype=float32)

# %%
prediksi=prediksi.flatten()

# %%
# prediksi1 = prediksi*(max-min) + min
# prediksi1

# %%
hasil=np.concatenate((series,prediksi))
asli = np.concatenate((series[:-2],series_t))

# %%
asli.shape
# Out:
# (60,)

# %%
hasil.shape
# Out:
# (60,)

# %%
# hasil = hasil * (max-min) + min
# series = series * (max-min) + min

# %%
plt.plot(asli,marker = 'o',label='data asli')
plt.plot(hasil,marker = 'o',label='data prediksi')
plt.title('penjualan produk cluster 1')
plt.legend()
plt.plot()
# Out:
# []

# %%
model.save('cluster1_newdata.h5')

# %% [markdown]
# # Satu Produk

# %%
def predict(idx):
    c = c1[c1.index==str(idx)]
    c.T.plot()
    c_t = c1_t[c1_t.index==str(idx)]
    new_c = []
    new_c_t=[]
    for a in c:
        new_c.append(c[a])
    for a in c_t:
        new_c_t.append(c_t[a])
    series = np.array(new_c)
    series_t = np.array(new_c_t)
    x_test =  series_t
    window_size=2
    test_x, test_y = time_data(x_test.flatten(), window_size)
    prediksi=model.predict(test_x)
    print(prediksi)
    prediksi=prediksi.flatten()
    series = series.flatten()
    series_t = series_t.flatten()
    hasil=np.concatenate((series,prediksi))
    asli = np.concatenate((series[:-2],series_t))
    plt.figure(figsize=(10,5))
    plt.plot(asli,marker = 'o',label='data asli')
    plt.plot(hasil,marker = 'o',label='data prediksi')
    plt.title('penjualan produk produk '+str(c.index[0]))
    plt.legend()
    plt.plot()

# %%
c1.index
# Out:
# Index(['18051', '04149', '04040', '18071', '18074'], dtype='object')

# %%
for a in c1.index:
    print("product code : "+ a)
    predict(a)
    print("==end==")
# Out:
# product code : 18051
# 1/1 [==============================] - 1s 1s/step
# [[24.267563]
#  [ 4.011532]
#  [45.613834]
#  [11.518865]
#  [16.45485 ]
#  [19.090956]]
# ==end==
# product code : 04149
# 1/1 [==============================] - 0s 23ms/step
# [[57.52497 ]
#  [54.73462 ]
#  [55.10647 ]
#  [81.674446]
#  [23.174911]
#  [19.275518]]
# ==end==
# product code : 04040
# 1/1 [==============================] - 0s 19ms/step
# [[19.584747]
#  [19.268723]
#  [18.80678 ]
#  [17.249533]
#  [16.809519]
#  [18.301216]]
# ==end==
# product code : 18071
# 1/1 [==============================] - 0s 17ms/step
# [[20.84156 ]
#  [21.291191]
#  [55.3009  ]
#  [23.159922]
#  [15.787688]
#  [17.23184 ]]
# ==end==
# product code : 18074
# 1/1 [==============================] - 0s 18ms/step
# [[50.23157 ]
#  [30.533056]
#  [29.793121]
#  [15.673025]
#  [21.594929]
#  [17.364775]]
# ==end==
